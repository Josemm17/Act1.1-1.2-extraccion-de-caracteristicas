# %% [markdown]
# # Actividad 1.1 (Extracción de Características)

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Leer el archivo de la ciudad
Rio=pd.read_csv("Rio_limpio.csv", index_col=0)

# %%
#Imprimo los primeros 5 registro del dataframe
Rio.head()
# Out:
#         source                                   name  host_since  \
# 0  city scrape      Unbelievable Ocean View Apartment  2011-11-19
# 1  city scrape    EXCELENTE APARTAMENTO EM COPACABANA  2013-07-15
# 2  city scrape                  Comfort em Copacabana  2011-11-20
# 3  city scrape       Amazing Huge Apartment in Leblon  2011-04-25
# 4  city scrape  Lindo quarto sossegado para temporada  2011-05-04
#
#             host_location  host_response_time host_is_superhost  \
# 0  Rio de Janeiro, Brazil  a few days or more                 f
# 1  Rio de Janeiro, Brazil        Sin registro                 f
# 2  Rio de Janeiro, Brazil      within an hour                 t
# 3  Rio de Janeiro, Brazil        Sin registro                 f
# 4  Rio de Janeiro, Brazil  within a few hours                 f
#
#   host_neighbourhood host_identity_verified           neighbourhood  \
# 0            Vidigal                      t  Rio de Janeiro, Brazil
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Rio)
# Out:
#             source  frequency  percentage  cumulative_perc
# 0      city scrape      36651    0.927897         0.927897
# 1  previous scrape       2848    0.072103         1.000000
#
# ----------------------------------------------------------------
#
#                                                  name  frequency  percentage  \
# 0                           Apartamento em Copacabana        138    0.003494
# 1                                Quarto em Copacabana         38    0.000962
# 2                              Apartamento Copacabana         38    0.000962
# 3                            Apartamento aconchegante         33    0.000835
# 4                Lindo Flat Vista Mar Barra da Tijuca         32    0.000810
# ...                                               ...        ...         ...
# 37441  Apartamento encantador com Vista para o Cristo          1    0.000025
# 37442                   Studio in Lapa-Rio de Janeiro          1    0.000025
# ...

# %% [markdown]
# ## Extraer características a partir de aplicar un análisis univariado, a diferentes variables categóricas (15). Mostrar los resultados obtenidos ,mediante gráficas y tablas

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['host_location'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>70]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('host_location')
print(Filtro1_index)


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "skyblue")
plt.title('Ubicación del host')
plt.xlabel('Ubicación')
plt.ylabel('Frecuencia')
# Out:
#                                  frequency
# host_location
# Rio de Janeiro, Brazil               24442
# Sin registro                          7646
# State of Rio de Janeiro, Brazil       2148
# Rio, Brazil                            846
# Brazil                                 707
# São Paulo, Brazil                      685
# Niterói, Brazil                        157
# Belo Horizonte, Brazil                 123
# New York, NY                            98
# Brasília, Brazil                        96
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(Rio['host_response_time'])
table2= table2.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro2= table2[table2['frequency']>1]

#Ajusto el indice de mi dataframe
Filtro2_index= Filtro2.set_index('host_response_time')
print(Filtro2_index)


#Realizamos grafico de barras del dataframe filtrado
Filtro2_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Tiempo de respuesta del host')
plt.xlabel('Tiempo de respuesta')
plt.ylabel('Frecuencia')
# Out:
#                     frequency
# host_response_time
# within an hour          21917
# within a few hours       6806
# Sin registro             3921
# within a day             3919
# a few days or more       2936
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(Rio['neighbourhood_cleansed'])
table3= table3.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro3= table3[table3['frequency']>200]

#Ajusto el indice de mi dataframe
Filtro3_index= Filtro3.set_index('neighbourhood_cleansed')
print(Filtro3_index)


#Realizamos grafico de barras del dataframe filtrado
Filtro3_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Vecindario del alojamiento')
plt.xlabel('Vecindario')
plt.ylabel('Frecuencia')
# Out:
#                           frequency
# neighbourhood_cleansed
# Copacabana                    12352
# Barra da Tijuca                3612
# Ipanema                        3570
# Recreio dos Bandeirantes       2060
# Jacarepaguá                    1848
# Leblon                         1767
# Botafogo                       1709
# Centro                         1660
# Santa Teresa                   1246
# Flamengo                        889
# Camorim                         798
# Leme                            776
# Laranjeiras                     539
# Tijuca                          417
# São Conrado                     407
# Catete                          355
# Glória                          309
# Vidigal                         284
# Lagoa                           278
# Gávea                           230
# Jardim Botânico                 205
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(Rio['property_type'])
table4= table4.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro4= table4[table4['frequency']>200]

#Ajusto el indice de mi dataframe
Filtro4_index= Filtro4.set_index('property_type')
print(Filtro4_index)


#Realizamos grafico de barras del dataframe filtrado
Filtro4_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "#ffbe33")
plt.title('Tipo de propiedad')
plt.xlabel('Propiedad')
plt.ylabel('Frecuencia')
# Out:
#                                    frequency
# property_type
# Entire rental unit                     25880
# Private room in rental unit             4512
# Entire home                             1877
# Entire condo                            1801
# Private room in home                    1360
# Entire loft                              790
# Entire serviced apartment                762
# Private room in condo                    399
# Room in hotel                            336
# Private room in bed and breakfast        334
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(Rio['room_type'])
table5= table5.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro5= table5[table5['frequency']>1]

#Ajusto el indice de mi dataframe
Filtro5_index= Filtro5.set_index('room_type')
print(Filtro5_index)

#Realizamos grafico de área del dataframe filtrado
Filtro5_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
#                  frequency
# room_type
# Entire home/apt      31728
# Private room          7483
# Shared room            260
# Hotel room              28
# <Axes: xlabel='room_type'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table6= freq_tbl(Rio['host_neighbourhood'])
table6= table6.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro6= table6[table6['frequency']>30]

#Ajusto el indice de mi dataframe
Filtro6_index= Filtro6.set_index('host_neighbourhood')
print(Filtro6_index)

#Realizamos grafico de área del dataframe filtrado
Filtro6_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
#                           frequency
# host_neighbourhood
# Copacabana                    10743
# Sin registro                   5535
# Barra da Tijuca                3199
# Ipanema                        3083
# Recreio dos Bandeirantes       1819
# Leblon                         1497
# Botafogo                       1398
# Centro                         1249
# Jacarepaguá                    1061
# Santa Teresa                    862
# Flamengo                        790
# Leme                            611
# Vidigal                         438
# Tijuca                          403
# Laranjeiras                     388
# São Conrado                     387
# Lapa                            317
# Glória                          277
# Camorim                         263
# Catete                          241
# Joá                             204
# Gávea                           173
# Itanhangá                       155
# Lagoa                           152
# ...

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['host_is_superhost'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('host_is_superhost')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                    frequency
# host_is_superhost
# f                      26088
# t                      12241
# Sin registro            1170
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8= freq_tbl(Rio['host_identity_verified'])
table8= table8.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro8= table8[table8['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro8_index= Filtro8.set_index('host_identity_verified')
print(Filtro8_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro8_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                         frequency
# host_identity_verified
# t                           33230
# f                            6267
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table9= freq_tbl(Rio['instant_bookable'])
table9_1= table9.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro9= table9_1[table9_1['frequency']>70]

#Ajusto el indice de mi dataframe
Filtro9_index= Filtro9.set_index('instant_bookable')
print(Filtro9_index)



#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
table9.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
#                   frequency
# instant_bookable
# f                     30524
# t                      8975
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table10= freq_tbl(Rio['instant_bookable'])
table10_1= table10.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro10= table10_1[table10_1['frequency']>70]

#Ajusto el indice de mi dataframe
Filtro10_index= Filtro10.set_index('instant_bookable')
print(Filtro10_index)



#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
table10.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
#                   frequency
# instant_bookable
# f                     30524
# t                      8975
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Corroboramos valores nulos
valores_nulos=Rio.isnull().sum()
valores_nulos
# Out:
# source                                          0
# name                                            0
# host_since                                      0
# host_location                                   0
# host_response_time                              0
# host_is_superhost                               0
# host_neighbourhood                              0
# host_identity_verified                          0
# neighbourhood                                   0
# neighbourhood_cleansed                          0
# property_type                                   0
# room_type                                       0
# has_availability                                0
# first_review                                    0
# last_review                                     0
# instant_bookable                                0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_listings_count                             0
# ...

# %% [markdown]
# ## Categorizar **host_response_rate**

# %%
#Calculamos el numero total de la población "n"
Rio['host_response_rate'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['host_response_rate'].max()
Min=Rio['host_response_rate'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [72.0, 100.0]
# 16.26066585429171
# 1.7219467056824063

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(71.99, 100.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['host_response_rate']=pd.cut(x= Rio['host_response_rate'], bins=intervalos, labels= categorias )
Rio['host_response_rate']
# Out:
# 0        Categoría15
# 1        Categoría10
# 2        Categoría16
# 3        Categoría10
# 4        Categoría16
#             ...
# 39494    Categoría16
# 39495    Categoría10
# 39496    Categoría16
# 39497    Categoría16
# 39498    Categoría10
# Name: host_response_rate, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['host_response_rate'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>70]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('host_response_rate')


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "skyblue")
plt.title('Porcentaje de respuesta del host')
plt.xlabel('Respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## Categorizar **host_acceptance_rate**

# %%
#Calculamos el numero total de la población "n"
Rio['host_acceptance_rate'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['host_acceptance_rate'].max()
Min=Rio['host_acceptance_rate'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [19.0, 100.0]
# 16.26066585429171
# 4.981345827152675

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(18.99, 100.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['host_acceptance_rate']=pd.cut(x= Rio['host_acceptance_rate'], bins=intervalos, labels= categorias )
Rio['host_acceptance_rate']
# Out:
# 0        Categoría13
# 1        Categoría12
# 2        Categoría16
# 3        Categoría12
# 4         Categoría1
#             ...
# 39494    Categoría16
# 39495    Categoría12
# 39496    Categoría16
# 39497    Categoría16
# 39498    Categoría12
# Name: host_acceptance_rate, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['host_acceptance_rate'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>70]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('host_acceptance_rate')


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "skyblue")
plt.title('Porcentaje de aceptación del host')
plt.xlabel('Aceptación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## Categorizar **host_total_listings_count**

# %%
#Calculamos el numero total de la población "n"
Rio['host_total_listings_count'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['host_total_listings_count'].max()
Min=Rio['host_total_listings_count'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [1.0, 21.0]
# 16.26066585429171
# 1.2299619326302902

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(0.99, 21.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['host_total_listings_count']=pd.cut(x= Rio['host_total_listings_count'], bins=intervalos, labels= categorias )
Rio['host_total_listings_count']
# Out:
# 0        Categoría2
# 1        Categoría2
# 2        Categoría5
# 3        Categoría1
# 4        Categoría5
#             ...
# 39494    Categoría3
# 39495    Categoría1
# 39496    Categoría1
# 39497    Categoría1
# 39498    Categoría1
# Name: host_total_listings_count, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['host_total_listings_count'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('host_total_listings_count')


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Total de alojamientos por host')
plt.xlabel('Alojamientos')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## Categorizar **accommodates**

# %%
#Calculamos el numero total de la población "n"
Rio['accommodates'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['accommodates'].max()
Min=Rio['accommodates'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [1.0, 9.0]
# 16.26066585429171
# 0.49198477305211613

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(0.99, 9.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['accommodates']=pd.cut(x= Rio['accommodates'], bins=intervalos, labels= categorias )
Rio['accommodates']
# Out:
# 0         Categoría7
# 1         Categoría7
# 2         Categoría3
# 3        Categoría10
# 4         Categoría1
#             ...
# 39494     Categoría7
# 39495    Categoría14
# 39496    Categoría10
# 39497    Categoría10
# 39498     Categoría7
# Name: accommodates, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['accommodates'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('accommodates')


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Capacidad de huespedes por alojamientos')
plt.xlabel('Capacidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## Categorizar **bathrooms**

# %%
#Calculamos el numero total de la población "n"
Rio['bathrooms'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['bathrooms'].max()
Min=Rio['bathrooms'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [0.0, 3.5]
# 16.26066585429171
# 0.21524333821030078

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(-0.99, 3.51, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['bathrooms']=pd.cut(x= Rio['bathrooms'], bins=intervalos, labels= categorias )
Rio['bathrooms']
# Out:
# 0         Categoría8
# 1         Categoría8
# 2         Categoría8
# 3        Categoría16
# 4         Categoría8
#             ...
# 39494    Categoría11
# 39495     Categoría8
# 39496     Categoría8
# 39497     Categoría9
# 39498     Categoría8
# Name: bathrooms, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['bathrooms'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('bathrooms')


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Cantidad de baños')
plt.xlabel('Baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## Categorizar **beds**

# %%
#Calculamos el numero total de la población "n"
Rio['beds'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['beds'].max()
Min=Rio['beds'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [0.0, 6.0]
# 16.26066585429171
# 0.36898857978908706

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(-0.99, 6.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['beds']=pd.cut(x= Rio['beds'], bins=intervalos, labels= categorias )
Rio['beds']
# Out:
# 0         Categoría7
# 1         Categoría5
# 2         Categoría7
# 3        Categoría10
# 4         Categoría5
#             ...
# 39494     Categoría7
# 39495     Categoría5
# 39496    Categoría12
# 39497     Categoría5
# 39498     Categoría7
# Name: beds, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Rio['beds'])
table1= table1.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro1= table1[table1['frequency']>1]

#Ajusto el indice de mi dataframe
Filtro1_index= Filtro1.set_index('beds')


#Realizamos grafico de barras del dataframe filtrado
Filtro1_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Cantidad de camas')
plt.xlabel('Camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ## Categorizar **price**

# %%
#Calculamos el numero total de la población "n"
Rio['price'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['price'].max()
Min=Rio['price'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [33.0, 2418.0]
# 16.26066585429171
# 146.67296046616212

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(32.99, 2418.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['price']=pd.cut(x= Rio['price'], bins=intervalos, labels= categorias )
Rio['price']
# Out:
# 0        Categoría2
# 1        Categoría5
# 2        Categoría8
# 3        Categoría6
# 4        Categoría1
#             ...
# 39494    Categoría7
# 39495    Categoría2
# 39496    Categoría5
# 39497    Categoría8
# 39498    Categoría9
# Name: price, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['price'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('price')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#              frequency
# price
# Categoría6        6465
# Categoría3        4730
# Categoría2        4579
# Categoría4        4331
# Categoría9        4188
# Categoría5        3656
# Categoría7        2802
# Categoría1        2176
# Categoría8        1942
# Categoría10       1306
# Categoría12        766
# Categoría11        716
# Categoría14        715
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## Categorizar **maximum_nights**

# %%
#Calculamos el numero total de la población "n"
Rio['maximum_nights'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: maximum_nights
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['maximum_nights'].max()
Min=Rio['maximum_nights'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [1.0, 800.0]
# 16.26066585429171
# 49.136979208580094

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(0.99, 800.01, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['maximum_nights']=pd.cut(x= Rio['maximum_nights'], bins=intervalos, labels= categorias )
Rio['maximum_nights']
# Out:
# 0        Categoría2
# 1        Categoría1
# 2        Categoría1
# 3        Categoría1
# 4        Categoría4
#             ...
# 39494    Categoría2
# 39495    Categoría8
# 39496    Categoría8
# 39497    Categoría1
# 39498    Categoría1
# Name: maximum_nights, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['maximum_nights'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('maximum_nights')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                 frequency
# maximum_nights
# Categoría8          14415
# Categoría1           9676
# Categoría5           7446
# Categoría2           6155
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## Categorizar **availability_365**

# %%
#Calculamos el numero total de la población "n"
Rio['availability_365'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  int64
# dtypes: int64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['availability_365'].max()
Min=Rio['availability_365'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [0, 365]
# 16.26066585429171
# 22.446805270502797

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(-0.99, 365.1, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['availability_365']=pd.cut(x= Rio['availability_365'], bins=intervalos, labels= categorias )
Rio['availability_365']
# Out:
# 0        Categoría12
# 1        Categoría15
# 2        Categoría15
# 3        Categoría16
# 4        Categoría13
#             ...
# 39494     Categoría4
# 39495    Categoría16
# 39496     Categoría7
# 39497     Categoría8
# 39498    Categoría16
# Name: availability_365, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['availability_365'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('availability_365')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                   frequency
# availability_365
# Categoría16            8003
# Categoría4             4537
# Categoría1             3948
# Categoría12            2934
# Categoría3             2651
# Categoría8             2611
# Categoría2             2439
# Categoría15            2131
# Categoría7             1816
# Categoría6             1619
# Categoría14            1536
# Categoría5             1426
# Categoría11            1231
# Categoría13            1005
# Categoría10             907
# Categoría9              705
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## Categorizar **number_of_reviews**

# %%
#Calculamos el numero total de la población "n"
Rio['number_of_reviews'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['number_of_reviews'].max()
Min=Rio['number_of_reviews'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [0.0, 62.0]
# 16.26066585429171
# 3.8128819911539

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(-0.99, 62.1, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['number_of_reviews']=pd.cut(x= Rio['number_of_reviews'], bins=intervalos, labels= categorias )
Rio['number_of_reviews']
# Out:
# 0        Categoría3
# 1        Categoría3
# 2        Categoría9
# 3        Categoría1
# 4        Categoría2
#             ...
# 39494    Categoría1
# 39495    Categoría1
# 39496    Categoría1
# 39497    Categoría1
# 39498    Categoría1
# Name: number_of_reviews, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['number_of_reviews'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('number_of_reviews')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                    frequency
# number_of_reviews
# Categoría1             15963
# Categoría3              7220
# Categoría2              5115
# Categoría4              2126
# Categoría5              1596
# Categoría6              1260
# Categoría7              1050
# Categoría8               937
# Categoría9               788
# Categoría10              718
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## Categorizar **review_scores_value**

# %%
#Calculamos el numero total de la población "n"
Rio['review_scores_value'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['review_scores_value'].max()
Min=Rio['review_scores_value'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [4.38, 5.0]
# 16.26066585429171
# 0.038128819911539005

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(4.37, 5.1, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['review_scores_value']=pd.cut(x= Rio['review_scores_value'], bins=intervalos, labels= categorias )
Rio['review_scores_value']
# Out:
# 0        Categoría10
# 1        Categoría11
# 2        Categoría13
# 3         Categoría8
# 4        Categoría10
#             ...
# 39494     Categoría8
# 39495     Categoría8
# 39496     Categoría8
# 39497     Categoría8
# 39498     Categoría8
# Name: review_scores_value, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['review_scores_value'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('review_scores_value')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                      frequency
# review_scores_value
# Categoría8               12015
# Categoría14               8439
# Categoría10               4761
# Categoría11               2607
# Categoría12               2223
# Categoría9                2199
# Categoría13               1850
# Categoría7                1459
# Categoría6                1150
# Categoría3                1088
# <Axes: ylabel='frequency'>

# %% [markdown]
# ## Categorizar **reviews_per_month**

# %%
#Calculamos el numero total de la población "n"
Rio['reviews_per_month'].info()
n=39499
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39499 entries, 0 to 39498
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 39499 non-null  float64
# dtypes: float64(1)
# memory usage: 617.2 KB

# %%
#Obtenemos el limite superior y el límite inferior de la columna objetivo
Max=Rio['reviews_per_month'].max()
Min=Rio['reviews_per_month'].min()
Limites= [Min, Max]
print(Limites)

#Calculamos el rango R
R=Max-Min
R

#Calculamos el número de Intervalos de Clase "ni", aplicando la regla de Sturges
ni= 1+3.32*np.log10(n)
print(ni)

#Calculamos el Ancho del Intervalo "i"
i=R/ni
i
# Out:
# [0.01, 2.49]
# 16.26066585429171
# 0.15251527964615602

# %%
#Categorización de variables
#Declaramos 2 intervalos (menores de 100) y (mayores de 100)
#Ajustamos los limites para que todos los valores sean incluidos en los intervalos
intervalos=np.linspace(0, 2.5, 17)

#Creamos las categorías 
categorias= ["Categoría1", "Categoría2","Categoría3", "Categoría4",
             "Categoría5", "Categoría6","Categoría7", "Categoría8",
             "Categoría9", "Categoría10","Categoría11","Categoría12",
             "Categoría13", "Categoría14", "Categoría15", "Categoría16"]

#Finalmente creamos las categorías en la columna numérica
Rio['reviews_per_month']=pd.cut(x= Rio['reviews_per_month'], bins=intervalos, labels= categorias )
Rio['reviews_per_month']
# Out:
# 0         Categoría1
# 1        Categoría15
# 2         Categoría2
# 3         Categoría8
# 4         Categoría1
#             ...
# 39494     Categoría8
# 39495     Categoría8
# 39496     Categoría8
# 39497     Categoría8
# 39498     Categoría8
# Name: reviews_per_month, Length: 39499, dtype: category
# Categories (16, object): ['Categoría1' < 'Categoría2' < 'Categoría3' < 'Categoría4' ... 'Categoría13' < 'Categoría14' < 'Categoría15' < 'Categoría16']

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(Rio['reviews_per_month'])
table7= table7.drop(['percentage','cumulative_perc'], axis=1)

#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro7= table7[table7['frequency']>700]

#Ajusto el indice de mi dataframe
Filtro7_index= Filtro7.set_index('reviews_per_month')
print(Filtro7_index)

#Realizamos grafico de pastel del dataframe filtrado
Filtro7_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
#                    frequency
# reviews_per_month
# Categoría8             11504
# Categoría6              5331
# Categoría1              5205
# Categoría2              3833
# Categoría4              2197
# Categoría3              2163
# Categoría5              1897
# Categoría7              1546
# Categoría10             1013
# Categoría13              858
# Categoría9               843
# Categoría11              813
# Categoría12              742
# <Axes: ylabel='frequency'>
